# %% [markdown]
#                                                                               Alem Fitwi

# %% [markdown]
# ## <div class="alert alert-success"> Math

# %% [markdown]
# - $Math:$
#     - $Roots(Numbers) \rightarrow$: Natural, whole numbers, rational, irrational, real, & complex
#     - $Trunk(Arithmetic) \rightarrow$: +, -, *, /, modulus, & exponentiation
#     - $Branches(Geometry, Algebra) \rightarrow$: geometry studies shapes and algebra studies how to solves equations
#     - $Leaves(Probability,\ Statistics,\ Calculus,\ Integral)$
#       - Probility: studies chances/likelihoods
#       - Statistics: data analytics
#       - Calculus: studies rate of change
#       - Integration: areas under curve
#
# - $Numbers:$
#     - $ Natural,\ N,\ (1, 2, 3) \rightarrow $
#     - $ Whole\ Numbers(0, 1, 2, 3) \rightarrow$
#     - $ Integers,\ Z,\ (-1, 0, 1) \rightarrow $
#     - $Rational,\ Q,\ (\frac{1}{3}, \frac{-11}{3}, 2.25) \rightarrow $
#     - $Real Algebraic/Irrational\ (\sqrt(2), \frac{1=\sqrt(5)}{2}) \rightarrow $
#     - $Real,\ R,\ (\pi, e, -2\pi, ...)\rightarrow $
#     - $Complex\ Numbers,\ C,\ (i=\sqrt(-1),\ -i,\ 2i)\rightarrow $

# %% [markdown]
# ## <div class="alert alert-warning"> Vocabularies

# %% [markdown]
# - **Math**: addends --> sum; minuend, subtrahend --> diff; dividend, divisor --> quotient; factors --> product
# -

# %%
import cv2
import numpy as np
import pandas as pd
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols
import statsmodels.api as sm
from scipy import stats

def showimg(img, title='', cmap='gray'):
    plt.imshow(img, cmap=cmap)
    plt.title(title)
    plt.show()

    return True

# %% [markdown]
# - Var: https://www.youtube.com/watch?v=igbNaVkjfQk
# - ANOVA: https://www.youtube.com/watch?v=g5HlLOwcXuI
# - REL: https://www.youtube.com/watch?v=BQXnKpP2lrI
# - DoE: https://www.youtube.com/watch?v=aKTaisrn0Fs
# - CPK/CPI: https://www.youtube.com/watch?v=H6St9mCKWuA
# - Xbar: https://www.youtube.com/watch?v=Aj7lJLR-7b4
# - Control Charts: https://www.youtube.com/watch?v=p-gvwkHePaU
# - 7QC Tools: https://www.youtube.com/watch?v=ZfQ6PLxDq1U
# - 7QC Tools: https://www.youtube.com/watch?v=IV9LRXCgtK0
# - OEE (Overall Equipment Effectiveness) – What is it and how to calculate it! https://www.youtube.com/watch?v=F9ETypl9aKg

# %% [markdown]
# ## <div class="alert alert-danger"> Statistics

# %% [markdown]
# ### Descriptive Statistics
# - Descriptcriptive Statistics is a branch of statistics that focuses on summarizing, organizing, and presenting data in a meaningful way. It helps in understanding the basic features of a dataset by providing simple summaries, often through numerical measures and visualizations.

# %% [markdown]
# - **Key Components of Descriptive Statistics**:
#  - Measures of Central Tendency (describe the center of the data):
#     - ***Mean (Average)***: Sum of all values divided by the number of values.
#     - ***Median***: Middle value when data is arranged in order.
#     - ***Mode***: Most frequently occurring value.
#  - Measures of Dispersion (describe the spread of data):
#      - ***Range***: Difference between the highest and lowest values.
#      - ***Variance***: Average of squared deviations from the mean.
#      - ***Standard Deviation***: Square root of variance (shows spread around the mean).
#      - ***Interquartile Range (IQR)***: Range of the middle 50% of data (Q3 - Q1).
#  - Shape of the Distribution:
#    - ***Skewness***: Measures asymmetry in data distribution.
#    - ***Kurtosis***: Measures the "tailedness" (peakedness or flatness) of the distribution.
#
#  - Frequency Distributions (counts of data points in categories):
#    - Tables: Frequency tables, contingency tables.
#    - Graphs: Histograms, bar charts, pie charts, box plots.
#
#  - Examples of Descriptive Statistics:
#    - The average salary of employees in a company.
#    - The range of test scores in a class.
#    - A histogram showing the distribution of ages in a population.

# %%
import scipy
import numpy as np #mean, median, ptp, var, std, quantile, percentile
from scipy import stats #mode, kurtosis, skew
from scipy.stats import iqr
import statistics #mean, median, mode, variance, 
#print(dir(scipy))

# %%
A=np.array([[10,14,11,7,9.5,15,19],[8,9,17,14.5,12,18,15.5],
  [15,7.5,11.5,10,10.5,7,11],[11.5,11,9,12,14,12,7.5]])
lst =[1,2,3,4,5,4]

# %%
np.mean(A, axis=0) #mean
# Out:
# array([11.125, 10.375, 12.125, 10.875, 11.5  , 13.   , 13.25 ])

# %%
np.mean(lst) #mean
# Out:
# 3.1666666666666665

# %%
np.median(lst) #median
# Out:
# 3.5

# %%
stats.mode(lst).mode,  stats.mode(lst).count# ModeResult(mode=4, count=2)
# Out:
# (4, 2)

# %%
np.ptp(lst) # range
# Out:
# 4

# %%
np.percentile(lst,27,interpolation='lower'), np.percentile(lst,27) # percentile
# Out:
# (2, 2.35)

# %%
np.quantile(lst,0.25,interpolation='lower'), np.quantile(lst,0.25), np.percentile(lst,25)
# Out:
# (2, 2.25, 2.25)

# %%
print("Range:",np.ptp(lst))
#np.percentile(lst,27,axis=0, interpolation='lower')
print("Percentile:",np.percentile(lst,27,interpolation='lower'))
print("Quantile:",np.quantile(lst,0.25,interpolation='lower'))
#iqr(B, axis=0 , rng=(25, 75), interpolation='lower')
print("IQR2575:",iqr(lst, axis=0 , rng=(25, 75), interpolation='lower'))
print("IQR5075:",iqr(lst, axis=0 , rng=(50, 75), interpolation='lower'))
#numpy.var(a, axis=None, dtype=None, ddof=0)
print("Variance:",np.var(lst,axis=0))
print("STD:",np.std(lst,axis=0))
print("Skewness", stats.skew(lst,axis=0))
print("Kurtosis:",stats.kurtosis(lst,axis=0,fisher=False)) #Pearson Kurtosis 
#print("Kurtosis:",stats.kurtosis(lst,axis=1)) #Fisher's Kurtosis
# Out:
# Range: 4
# Percentile: 2
# Quantile: 2
# IQR2575: 2
# IQR5075: 1
# Variance: 1.8055555555555556
# STD: 1.3437096247164249
# Skewness -0.30531626975805126
# Kurtosis: 1.848284023668639

# %% [markdown]
# ### Inferential Statistics
# - Descriptive Statistics summarizes existing data. Inferential Statistics makes predictions or generalizations about a population based on sample data (e.g., hypothesis testing, confidence intervals).
# - Inferential Statistics involves using sample data to make generalizations, predictions, or conclusions about a larger population. Unlike descriptive statistics (which summarizes data), inferential statistics helps in testing hypotheses and estimating parameters.
# - Key Concepts:
#     - Estimation
#       - Point Estimate: A single value estimate (e.g., sample mean).
#       - Confidence Interval: A range within which the population parameter likely falls (e.g., 95% CI).
#     - Hypothesis Testing
#       - Tests claims about population parameters (e.g., t-tests, ANOVA, chi-square).
#       - Uses p-values to determine statistical significance.
#     - Regression & Correlation
#       - Examines relationships between variables (e.g., linear regression).
#
# - Common Methods:
#   - t-tests (compare means)
#   - ANOVA (compare multiple groups)
#   - Chi-square tests (categorical data)
#   - Regression analysis (predict outcomes)
#
# - Purpose:
#   - Draw conclusions beyond the immediate data.
#   - Make data-driven decisions under uncertainty.

# %% [markdown]
# ## <div class="alert alert-info"> Probability

# %% [markdown]
# ## <div class="alert alert-success"> Combinatorics

# %% [markdown]
# ## <div class="alert alert-warning"> Gage Repeatability and Reproducibility (GRR)
# - Measurement Systems Analysis And Build Yield Mearement

# %% [markdown]
# #### 1. Measurement System Analysis(MSA)
# - Calculate, Analyze, and interpret measurment system capability using GR&R studies, measurment correlations, bias, linearity, percent agreement, and precision/tolerance (P/T)
# - General Steps:
#   - Define The Problem
#   - Measure The Problem and Process
#   - Analyze Data To Determine The Root Cause
#   - Improve The Process
#   - Control The Process and Product
#
#
# #### 2. Terms and Definitions
# - What is Measurment System Analysis(MSA)?
#   - Measurement systems have variations just like every other process.
#   - All Measurments have small or big systematic or random variations.
#   - Variations:
#     - Process variation
#     - Measurement Variation:GRR is performed to quantify this variation.
#     - For a measurement system(or tester) to be capable, the measurment system variation must be small relative to th design tolerance ($\pm$ or the process variation.
# - The Average and Range Method
#   - Repeatability: $Equipment\ Variation(EV)\ =\ \sigma_{Repeatability}\ =\ \frac{\bar{\bar{R}}}{d_2}$
#   - Reproducibility: $Appraiser\ Variation(AV)\ =\ \sigma_{Reproducibility}\ =\ \sqrt{(\frac{R_o}{d_2})^2 -\frac{EV^2}{n\times r}}$
#   - Gauge R & R: $Measurement\ System\ Variation(GRR) =\ \sigma_{GRR}\ =\ \sqrt{EV^2 + AV^2}$
#     - OPT/OST or APT/AST: $Operator/Appraiser||Parts/Samples||Trials\ 3x10x3$
#   - Part To Part Variation: $PV =\ \sigma_{p}\ =\ \frac{R_p}{d_2}$
#   - Total Variation: $TV =\ \sigma_{p}\ =\ \sqrt{GRR^2 + PV^2}$
#
# #### 3. The Gauge R & R Process
# - The purpose of GRR is to confirm that a measurment system is capable for its intended use.
# - There are two methods for assessing acceptability or capability of a measurement system.
#   - A. **The Precision/Tolerance Ratio (%Tolerance)**: Used if the measurement system is meant for ***product control*** (testing of product for coformance to a specification).
#     - Compare measurments against specification limits.
#
#   - B. **The Percent(%) of Total Process Variation (% Study Variation)**: used if the meaurement system is meant for ***process control(SPC)***, where the meaasurment variation is compared against total process variation.
#      - All Measurements are put into a control chart to evaluate and control the process.
#   - Both methods translate your measurment variation into a percentage value for evaluation.
#
#   - Pick the right method before you start the evaluation!
#
# ##### 3.1 The Precision/Tolerance Ratio (%Tolerance)
# - For a measurement system to be capable of meeting your needs, the normal variations (error) associated with the measurement system must be small compared to the design tolerance of the feature being measured.
# - Evaluates Conformance to specification.
# $$Precision\ Tolerance\ Ratio\ =\ \frac{Precision}{Tolerance}\ =\ \frac{Total\ Measurement\ System\ Variation}{Product\ Design\ Tolerance}$$
# $$Precision\ Tolerance\ Ratio\ =\  \frac{6\times \sigma_{GRR}}{Upper\ Spec(USL) - Lower\ Spec(LSL)}$$
# - $6\sigma (\pm 3\sigma)$ represents a $99.73\%$ spread, which is used to represent the "full' spread of measurment variation (5.15 = 99%).

# %%
display(Image.open('./pics/threesigma.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1262x420>

# %% [markdown]
# - ***Interpretation***:  The P/T Ratio is the portion (percentage) of the tolerance range that is consumed by the measurment variation exclusively.
# ##### 3.2 The Percent(%) of Total Process Variation (% Study Variation), or Part To Part Variation
# - For the measurment su=ystem to be capable of meeting your needs, the normal variation (error) associated with the measurment system must be small compared tot he totalmeasured variation of the feature being measured.
#   - No need to do the full spread; only $1 \sigma$ will do!
# $$Percent\ Variation\ =\ \frac{Measurment\ System\ Varition(GRR)}{Total\ Measurment\ Variation}\ =\ \frac{1\sigma}{1\sigma}$$
# - Interpretation:
#   - Measures What percentage of the variation came from the measurement and what percentage came from the process (part by part variation) variation.
#   - $Percent\ Variation\ =\ \frac{0.5496}{3.0802}\times 100\%\ =\ 17.8\%$ came from the measurement system and the rest from the process variations.
#   - The percent of variation reflects the portion (percentage) of the total variation that is consumed by the measurment system variation.

# %%
display(Image.open('./pics/tpvarn.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1131x325>

# %% [markdown]
# #### 4. Interpreting Results
# - For a measurement system to be capable of meeting your needs, the normal variation (error) associated with the measurement system must be small compared to the total measured variation of the feature being measured.
# - Generally, if the measurment system variation (error) is $<10\%$, then the measurment system is considered acceptable or capable.
# - If the measurement variation is between $10\%$ and $30\%$, then the measurement system is generally considered acceptable; however, consideration should be given for risk, application, and cost. ***Grey Area***.
# - If the measurment variation is greater than 30%, then the measurment system is usually not considered acceeptable.

# %%
display(Image.open('./pics/interpgrr.png')) # Src: Internet
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1533x360>

# %%
display(Image.open('./pics/totfin.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1555x686>

# %% [markdown]
# ### GRR Template

# %%
display(Image.open('./pics/grr_template.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1377x532>

# %% [markdown]
# ### Gage Repeatability and Reproducibility (GRR) Pythonic Implementation

# %%
class GageRR:
    
    def gage_rr(data, operator_col='Operator', part_col='Part', measurement_col='Measurement', 
                alpha=0.05, tolerance=None, print_results=True, plot_results=True):
        """
        Perform Gage R&R (Repeatability and Reproducibility) analysis.
        
        Parameters:
        -----------
        data : pandas.DataFrame
            Input data containing operators, parts, and measurements
        operator_col : str
            Column name for operators/appraisers
        part_col : str
            Column name for parts
        measurement_col : str
            Column name for measurements
        alpha : float
            Significance level for ANOVA (default 0.05)
        tolerance : float or None
            If provided, will calculate % of tolerance metrics
        print_results : bool
            Whether to print the results summary
        plot_results : bool
            Whether to generate plots
            
        Returns:
        --------
        dict
            Dictionary containing all Gage R&R metrics and components
        """
        
        # Prepare data
        operators = data[operator_col].astype('category')
        parts = data[part_col].astype('category')
        measurements = data[measurement_col]
        
        n_operators = len(operators.cat.categories)
        n_parts = len(parts.cat.categories)
        n_replicates = len(data) / (n_operators * n_parts)
        
        # Calculate basic statistics
        grand_mean = measurements.mean()
        part_means = data.groupby(part_col)[measurement_col].mean()
        operator_means = data.groupby(operator_col)[measurement_col].mean()
        
        # Calculate ranges
        range_df = data.groupby([operator_col, part_col])[measurement_col].agg(lambda x: x.max() - x.min())
        range_df = range_df.reset_index()
        range_df = range_df.rename(columns={measurement_col: 'Range'})
        
        # Calculate average range (for EV calculation)
        R_bar = range_df['Range'].mean()
        d2 = GageRR.get_d2_value(n_replicates)
        K1 = 1 / d2
        
        # Calculate operator ranges (for AV calculation)
        operator_range = operator_means.max() - operator_means.min()
        d2_star = GageRR.get_d2_star_value(n_operators)
        K2 = 1 / d2_star
        
        # Perform ANOVA
        model = ols(f'{measurement_col} ~ C({part_col}) + C({operator_col}) + C({part_col}):C({operator_col})', 
                    data=data).fit()
        anova_table = sm.stats.anova_lm(model, typ=2)
        
        # Calculate variance components
        MS_parts = anova_table['sum_sq'][f'C({part_col})']
        MS_operators = anova_table['sum_sq'][f'C({operator_col})']
        MS_interaction = anova_table['sum_sq'][f'C({part_col}):C({operator_col})']
        MS_repeatability = anova_table['sum_sq']['Residual'] if 'Residual' in anova_table.index else MS_interaction
        
        # Calculate variance components using ANOVA method
        var_repeatability = MS_repeatability
        var_reproducibility = max(0, (MS_operators - MS_interaction) / (n_parts * n_replicates))
        var_interaction = max(0, (MS_interaction - MS_repeatability) / n_replicates)
        
        var_operators = max(0, var_reproducibility)
        var_parts = max(0, (MS_parts - MS_interaction) / (n_operators * n_replicates))
        
        var_total = var_repeatability + var_reproducibility + var_interaction + var_parts
        var_gage_rr = var_repeatability + var_reproducibility + var_interaction
        
        # Calculate standard deviations
        sd_repeatability = np.sqrt(var_repeatability)
        sd_reproducibility = np.sqrt(var_reproducibility)
        sd_interaction = np.sqrt(var_interaction) if var_interaction > 0 else 0
        sd_operators = np.sqrt(var_operators)
        sd_parts = np.sqrt(var_parts)
        sd_total = np.sqrt(var_total)
        sd_gage_rr = np.sqrt(var_gage_rr)
        
        # Calculate study variation (6 sigma)
        study_var_repeatability = 6 * sd_repeatability
        study_var_reproducibility = 6 * sd_reproducibility
        study_var_interaction = 6 * sd_interaction
        study_var_operators = 6 * sd_operators
        study_var_parts = 6 * sd_parts
        study_var_total = 6 * sd_total
        study_var_gage_rr = 6 * sd_gage_rr
        
        # Calculate percent contributions
        pc_repeatability = 100 * var_repeatability / var_total
        pc_reproducibility = 100 * var_reproducibility / var_total
        pc_interaction = 100 * var_interaction / var_total
        pc_operators = 100 * var_operators / var_total
        pc_parts = 100 * var_parts / var_total
        pc_gage_rr = 100 * var_gage_rr / var_total
        
        # Calculate ndc (number of distinct categories)
        ndc = max(1, int(1.41 * (var_parts / var_gage_rr)**0.5))
        
        # Calculate EV, AV, GRR using average and range method
        EV = R_bar * K1
        AV = np.sqrt((operator_range * K2)**2 - (EV**2 / (n_parts * n_replicates)))
        GRR = np.sqrt(EV**2 + AV**2)
        PV = (part_means.max() - part_means.min()) * GageRR.get_k3_value(n_parts)
        TV = np.sqrt(GRR**2 + PV**2)
        
        # Calculate %GRR and %PV
        percent_GRR = 100 * GRR / TV
        percent_EV = 100 * EV / TV
        percent_AV = 100 * AV / TV
        percent_PV = 100 * PV / TV
    
        # Calculate %Tolerance if tolerance is provided
        if tolerance is not None:
            percent_tol_GRR = 100 * GRR / tolerance
            percent_tol_EV = 100 * EV / tolerance
            percent_tol_AV = 100 * AV / tolerance
        else:
            percent_tol_GRR = percent_tol_EV = percent_tol_AV = None
        
        # Prepare results dictionary
        results = {
            'ANOVA Table': anova_table,
            'Variance Components': {
                'Repeatability (EV)': var_repeatability,
                'Reproducibility (AV)': var_reproducibility,
                'Interaction': var_interaction,
                'Operators': var_operators,
                'Parts': var_parts,
                'Total': var_total,
                'Gage R&R': var_gage_rr
            },
            'Standard Deviations': {
                'Repeatability (EV)': sd_repeatability,
                'Reproducibility (AV)': sd_reproducibility,
                'Interaction': sd_interaction,
                'Operators': sd_operators,
                'Parts': sd_parts,
                'Total': sd_total,
                'Gage R&R': sd_gage_rr
            },
            'Study Variation (6*SD)': {
                'Repeatability (EV)': study_var_repeatability,
                'Reproducibility (AV)': study_var_reproducibility,
                'Interaction': study_var_interaction,
                'Operators': study_var_operators,
                'Parts': study_var_parts,
                'Total': study_var_total,
                'Gage R&R': study_var_gage_rr
            },
            'Percent Contribution': {
                'Repeatability (EV)': pc_repeatability,
                'Reproducibility (AV)': pc_reproducibility,
                'Interaction': pc_interaction,
                'Operators': pc_operators,
                'Parts': pc_parts,
                'Gage R&R': pc_gage_rr
            },
            'Average and Range Method': {
                'EV': EV,
                'AV': AV,
                'GRR': GRR,
                'PV': PV,
                'TV': TV,
                '%EV': percent_EV,
                '%AV': percent_AV,
                '%GRR': percent_GRR,
                '%PV': percent_PV,
                '%Tolerance GRR': percent_tol_GRR,
                '%Tolerance EV': percent_tol_EV,
                '%Tolerance AV': percent_tol_AV,
            },
            'Number of Distinct Categories': ndc,
            'Data Summary': {
                'Number of Operators': n_operators,
                'Number of Parts': n_parts,
                'Number of Replicates': n_replicates,
                'Grand Mean': grand_mean
            }
        }
        
        if print_results:
            GageRR.print_gage_rr_results(results, tolerance)
            
        if plot_results:
            GageRR.plot_gage_rr_charts(data, operator_col, part_col, measurement_col, results)
        
        return results
    
    def get_d2_value(m):
        """Get d2 value for bias correction factor based on number of replicates"""
        d2_table = {
            2: 1.128,
            3: 1.693,
            4: 2.059,
            5: 2.326,
            6: 2.534,
            7: 2.704,
            8: 2.847,
            9: 2.970,
            10: 3.078
        }
        return d2_table.get(m, 1.0)  # Default to 1.0 if m not in table
    
    def get_d2_star_value(g):
        """Get d2* value for bias correction factor based on number of operators"""
        d2star_table = {
            2: 1.41,
            3: 1.91,
            4: 2.24,
            5: 2.48,
            6: 2.67,
            7: 2.83,
            8: 2.96,
            9: 3.08,
        10: 3.18
        }
        return d2star_table.get(g, 1.0)  # Default to 1.0 if g not in table

    def get_k3_value(n):
        """Get K3 constant based on number of parts"""
        k3_table = {
            2: 0.7071,
            3: 0.5231,
            4: 0.4467,
            5: 0.4030,
            6: 0.3742,
            7: 0.3534,
            8: 0.3375,
            9: 0.3249,
            10: 0.3146
        }
        return k3_table.get(n, 1.0)  # Default to 1.0 if n not in table

    def print_gage_rr_results(results, tolerance=None):
        """Print formatted Gage R&R results"""
        print("\n" + "="*80)
        print("GAGE R&R (REPEATABILITY AND REPRODUCIBILITY) ANALYSIS")
        print("="*80)
        
        # Print data summary
        print("\nDATA SUMMARY:")
        print(f"Number of Operators: {results['Data Summary']['Number of Operators']}")
        print(f"Number of Parts: {results['Data Summary']['Number of Parts']}")
        print(f"Number of Replicates: {results['Data Summary']['Number of Replicates']}")
        print(f"Grand Mean: {results['Data Summary']['Grand Mean']:.4f}")
    
        # Print ANOVA table
        print("\nANOVA TABLE:")
        print(results['ANOVA Table'])
        
        # Print variance components
        print("\nVARIANCE COMPONENTS:")
        for name, value in results['Variance Components'].items():
            print(f"{name:<25}: {value:.6f}")
        
        # Print standard deviations
        print("\nSTANDARD DEVIATIONS:")
        for name, value in results['Standard Deviations'].items():
            print(f"{name:<25}: {value:.6f}")
        
        # Print study variation
        print("\nSTUDY VARIATION (6 * SD):")
        for name, value in results['Study Variation (6*SD)'].items():
            print(f"{name:<25}: {value:.6f}")
        
        # Print percent contribution
        print("\nPERCENT CONTRIBUTION:")
        for name, value in results['Percent Contribution'].items():
            print(f"{name:<25}: {value:.2f}%")
    
        # Print average and range method results
        print("\nAVERAGE AND RANGE METHOD RESULTS:")
        print(f"{'Repeatability (EV)':<25}: {results['Average and Range Method']['EV']:.6f}")
        print(f"{'Reproducibility (AV)':<25}: {results['Average and Range Method']['AV']:.6f}")
        print(f"{'Gage R&R (GRR)':<25}: {results['Average and Range Method']['GRR']:.6f}")
        print(f"{'Part Variation (PV)':<25}: {results['Average and Range Method']['PV']:.6f}")
        print(f"{'Total Variation (TV)':<25}: {results['Average and Range Method']['TV']:.6f}")
        print(f"{'%EV':<25}: {results['Average and Range Method']['%EV']:.2f}%")
        print(f"{'%AV':<25}: {results['Average and Range Method']['%AV']:.2f}%")
        print(f"{'%GRR':<25}: {results['Average and Range Method']['%GRR']:.2f}%")
        print(f"{'%PV':<25}: {results['Average and Range Method']['%PV']:.2f}%")
        
        if tolerance is not None:
            print("\nPERCENT OF TOLERANCE:")
            print(f"{'%Tolerance (EV)':<25}: {results['Average and Range Method']['%Tolerance EV']:.2f}%")
            print(f"{'%Tolerance (AV)':<25}: {results['Average and Range Method']['%Tolerance AV']:.2f}%")
            print(f"{'%Tolerance (GRR)':<25}: {results['Average and Range Method']['%Tolerance GRR']:.2f}%")
        
        # Print number of distinct categories
        print(f"\nNUMBER OF DISTINCT CATEGORIES (ndc): {results['Number of Distinct Categories']}")
    
        # Print interpretation
        print("\nINTERPRETATION:")
        grr_percent = results['Average and Range Method']['%GRR']
        if grr_percent <= 10:
            print("The measurement system is EXCELLENT (<= 10% of total variation)")
        elif grr_percent <= 30:
            print("The measurement system is ACCEPTABLE (<= 30% of total variation)")
        else:
            print("The measurement system NEEDS IMPROVEMENT (> 30% of total variation)")
    
        ndc = results['Number of Distinct Categories']
        if ndc >= 5:
            print(f"The measurement system can distinguish {ndc} categories - GOOD")
        elif ndc >= 2:
            print(f"The measurement system can distinguish {ndc} categories - MARGINAL")
        else:
            print("The measurement system cannot distinguish part variation - NEEDS IMPROVEMENT")
        
        print("="*80 + "\n")

    def plot_gage_rr_charts(data, operator_col, part_col, measurement_col, results):
        """Generate Gage R&R charts"""
        plt.figure(figsize=(15, 10))
        
        # X-bar chart by operator
        plt.subplot(2, 2, 1)
        operator_means = data.groupby([operator_col, part_col])[measurement_col].mean().unstack()
        for operator in operator_means.index:
            plt.plot(operator_means.columns, operator_means.loc[operator], 'o-', label=f'Operator {operator}')
        plt.axhline(results['Data Summary']['Grand Mean'], color='k', linestyle='--')
        plt.title('X-bar Chart by Operator')
        plt.xlabel('Part')
        plt.ylabel('Mean Measurement')
        plt.legend()
        plt.grid()
    
        # R chart
        plt.subplot(2, 2, 2)
        range_df = data.groupby([operator_col, part_col])[measurement_col].agg(lambda x: x.max() - x.min())
        range_df = range_df.unstack()
        for operator in range_df.index:
            plt.plot(range_df.columns, range_df.loc[operator], 'o-', label=f'Operator {operator}')
        plt.axhline(range_df.values.mean(), color='k', linestyle='--')
        plt.title('Range Chart')
        plt.xlabel('Part')
        plt.ylabel('Range')
        plt.legend()
        plt.grid()
        
        # Components of variation
        plt.subplot(2, 2, 3)
        components = {
            'Repeatability': results['Percent Contribution']['Repeatability (EV)'],
            'Reproducibility': results['Percent Contribution']['Reproducibility (AV)'],
            'Part Variation': results['Percent Contribution']['Parts']
        }
        plt.bar(components.keys(), components.values())
        plt.title('Components of Variation')
        plt.ylabel('Percent Contribution')
        plt.grid()
    
        # Operator Part Interaction
        plt.subplot(2, 2, 4)
        interaction_data = data.groupby([operator_col, part_col])[measurement_col].mean().unstack()
        for part in interaction_data.columns:
            plt.plot(interaction_data.index, interaction_data[part], 'o-', label=f'Part {part}')
        plt.title('Operator Part Interaction')
        plt.xlabel('Operator')
        plt.ylabel('Mean Measurement')
        plt.legend()
        plt.grid()
        
        plt.tight_layout()
        plt.show()

    def get_sample_data():
        # Example data (typical Gage R&R study format)
        example_data= pd.DataFrame({
            'Operator': ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A',
                         'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
                         'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C'],
            'Part': [1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 
                     1, 1, 1, 2, 2, 2, 3, 3, 3, 4,
                     1, 1, 1, 2, 2, 2, 3, 3, 3, 4],
            'Measurement': [21.2, 21.3, 21.4, 22.7, 22.8, 22.9, 23.0, 23.1, 23.2, 24.1,
                           21.1, 21.2, 21.3, 22.6, 22.7, 22.8, 23.1, 23.2, 23.3, 24.2,
                           21.3, 21.4, 21.5, 22.8, 22.9, 23.0, 23.2, 23.3, 23.4, 24.3]
        })
        
        return example_data

# %%
# Run Gage R&R analysis with example data
results = GageRR.gage_rr(GageRR.get_sample_data(), tolerance=5.0)  # Using tolerance=5.0 for %Tolerance calculations
# Out:
# ================================================================================
# GAGE R&R (REPEATABILITY AND REPRODUCIBILITY) ANALYSIS
# ================================================================================
#
# DATA SUMMARY:
# Number of Operators: 3
# Number of Parts: 4
# Number of Replicates: 2.5
# Grand Mean: 22.6100
#
# ANOVA TABLE:
#                      sum_sq    df      F        PR(>F)
# C(Part)              26.487   3.0  882.9  1.021858e-19
# C(Operator)           0.152   2.0    7.6  4.047714e-03
# C(Part):C(Operator)   0.048   6.0    0.8  5.824738e-01
# Residual              0.180  18.0    NaN           NaN
#
# VARIANCE COMPONENTS:
# Repeatability (EV)       : 0.180000
# Reproducibility (AV)     : 0.010400
# Interaction              : 0.000000
# Operators                : 0.010400
# Parts                    : 3.525200
# Total                    : 3.715600
# Gage R&R                 : 0.190400
#
# STANDARD DEVIATIONS:
# Repeatability (EV)       : 0.424264
# Reproducibility (AV)     : 0.101980
# Interaction              : 0.000000
# Operators                : 0.101980
# Parts                    : 1.877552
# Total                    : 1.927589
# Gage R&R                 : 0.436348
#
# STUDY VARIATION (6 * SD):
# Repeatability (EV)       : 2.545584
# Reproducibility (AV)     : 0.611882
# Interaction              : 0.000000
# Operators                : 0.611882
# Parts                    : 11.265310
# Total                    : 11.565535
# Gage R&R                 : 2.618091
#
# PERCENT CONTRIBUTION:
# Repeatability (EV)       : 4.84%
# Reproducibility (AV)     : 0.28%
# Interaction              : 0.00%
# Operators                : 0.28%
# Parts                    : 94.88%
# Gage R&R                 : 5.12%
#
# AVERAGE AND RANGE METHOD RESULTS:
# Repeatability (EV)       : 0.150000
# Reproducibility (AV)     : 0.069046
# Gage R&R (GRR)           : 0.165128
# Part Variation (PV)      : 1.295430
# Total Variation (TV)     : 1.305912
# %EV                      : 11.49%
# %AV                      : 5.29%
# %GRR                     : 12.64%
# %PV                      : 99.20%
#
# PERCENT OF TOLERANCE:
# %Tolerance (EV)          : 3.00%
# %Tolerance (AV)          : 1.38%
# %Tolerance (GRR)         : 3.30%
#
# NUMBER OF DISTINCT CATEGORIES (ndc): 6
#
# INTERPRETATION:
# The measurement system is ACCEPTABLE (<= 30% of total variation)
# The measurement system can distinguish 6 categories - GOOD
# ================================================================================

# %%
results
# Out:
# {'ANOVA Table':                      sum_sq    df      F        PR(>F)
#  C(Part)              26.487   3.0  882.9  1.021858e-19
#  C(Operator)           0.152   2.0    7.6  4.047714e-03
#  C(Part):C(Operator)   0.048   6.0    0.8  5.824738e-01
#  Residual              0.180  18.0    NaN           NaN,
#  'Variance Components': {'Repeatability (EV)': 0.17999999999999802,
#   'Reproducibility (AV)': 0.010400000000001672,
#   'Interaction': 0,
#   'Operators': 0.010400000000001672,
#   'Parts': 3.525200000000054,
#   'Total': 3.7156000000000535,
#   'Gage R&R': 0.19039999999999968},
#  'Standard Deviations': {'Repeatability (EV)': 0.4242640687119262,
#   'Reproducibility (AV)': 0.1019803902718639,
#   'Interaction': 0,
#   'Operators': 0.1019803902718639,
#   'Parts': 1.8775515971605292,
#   'Total': 1.9275891678467312,
#   'Gage R&R': 0.4363484845854282},
#  'Study Variation (6*SD)': {'Repeatability (EV)': 2.545584412271557,
#   'Reproducibility (AV)': 0.6118823416311834,
#   'Interaction': 0,
#   'Operators': 0.6118823416311834,
#   'Parts': 11.265309582963175,
#   'Total': 11.565535007080387,
#   'Gage R&R': 2.618090907512569},
#  'Percent Contribution': {'Repeatability (EV)': 4.844439659812559,
#   'Reproducibility (AV)': 0.27990095812255145,
#   'Interaction': 0.0,
#   'Operators': 0.27990095812255145,
#   'Parts': 94.8756593820649,
#   'Gage R&R': 5.124340617935109},
#  'Average and Range Method': {'EV': 0.14999999999999947,
#   'AV': 0.06904601000811056,
#   'GRR': 0.1651282880006934,
#   'PV': 1.295430000000001,
#   'TV': 1.3059120324118476,
#   '%EV': 11.486225433038488,
#   '%AV': 5.287186908033282,
#   '%GRR': 12.644671608984503,
#   '%PV': 99.19734008480742,
#   '%Tolerance GRR': 3.302565760013868,
#   '%Tolerance EV': 2.9999999999999893,
#   '%Tolerance AV': 1.3809202001622112},
#  'Number of Distinct Categories': 6,
#  'Data Summary': {'Number of Operators': 3,
#   'Number of Parts': 4,
#   'Number of Replicates': 2.5,
#   'Grand Mean': 22.61}}

# %% [markdown]
# ## <div class="alert alert-success"> ANOVA

# %% [markdown]
# ### ANOVA: ANalysis Of VAriance

# %% [markdown]
# #### Terminologies
# - Common Terms
#     - Designed Experiement (DoE, Design of Experiment)
#     - Independent Variables, Factors
#     - Dependent Variables, Responses
#     - Levels or Treatments
#     - Null or Alternative Hypothesis
#
# - ANOVA Analysis is paired with a Designed Experiment to determine if an independent variable has an effect on a dependent variable.
# - DoE Example: Does Octane Level/number (87, 89, 91, or 93) Impact Horsepower?
#   - Factor A: Octane Gas (Octane 87, Octane 89, Octane 91, or Octane 93).
#     - The independent variable is called a Factor and it is the controllable variables.
#     - Factors are varied at different levels which are different set-points of a factor.
#   - The dependent variable is called the response variable, Horsepower in this DoE.
#     - Does changing the Octane number impact the HorsePower? Does Hosepower depend on Octane Gas Number?
# - Interpretation:
# |Variation Source|Sum of Squares|Degrees of Freedom|Mean Squares|F-Value|
# |---|---|---|---|---|
# |Treatments(Between)|||||
# |Error(Within)|||||
# |Total|||||
#
# - F-Value tells us whethere there is a significantly impact. Besides, it enables us to accept/reject decision on the Null Hypothesis.
#
# - The **Null Hypothesis** is always the same- that all of our sample mean values are equal. That is, the average Horspower across all 4 levels will be the same.
#     - $H_o: \mu_a= \mu_b = \mu_c=...\mu_k$ Factors have no impact on output or response
#
# - ***Alternative Hypothesis*** : At least one of the Factors impacts responses. That is, no all means are equal.
#     - $H_a$: Not all means are equal
#     -  At least one mean value is different than the rest
#     - $H_a: \mu_a= \mu_b != \mu_c !=...\mu_k$ Factors have impact on output or response
#     - The Alternative Hypothesis is that the independent variable effects the dependent variable.
#
# - Q: how do make acceptt/reject decision for our hypothesis test?
# $$f-value\ =\ \frac{variance_a}{variance_b}\ =\ \frac{S^2_a}{S^2_b}\ =\ \frac{MST}{MSE}$$

# %% [markdown]
# #### Example Data for Cotane 87, 89, 91, & 93
# - Executing the experiment

# %%
import pandas as pd
data = {
    'octane87': [168.8, 171.5, 172.6, 168.1, 167.1, 170.9, 168.3, 169.2, 168.4, 171.8],
    'octane89': [178, 178, 173.6, 173.7, 172.8, 176.4, 172.9, 178.5, 176.8, 172.3],
    'octane91': [179.9, 183.4, 180.1, 181.8, 179.4, 183.9, 184.2, 184.0, 183.3, 182.5],
    'octane93': [185.3, 189.7, 187.1, 187.7, 186.2, 188.3, 186.6, 191.2, 187.4, 185.4]
}

df = pd.DataFrame(data)
df
# Out:
#    octane87  octane89  octane91  octane93
# 0     168.8     178.0     179.9     185.3
# 1     171.5     178.0     183.4     189.7
# 2     172.6     173.6     180.1     187.1
# 3     168.1     173.7     181.8     187.7
# 4     167.1     172.8     179.4     186.2
# 5     170.9     176.4     183.9     188.3
# 6     168.3     172.9     184.2     186.6
# 7     169.2     178.5     184.0     191.2
# 8     168.4     176.8     183.3     187.4
# 9     171.8     172.3     182.5     185.4

# %%
df['octane87'].mean(), df['octane89'].mean(), df['octane91'].mean(), df['octane93'].mean()
# Out:
# (169.67000000000002, 175.3, 182.25, 187.49)

# %%
gm = df.to_numpy().mean()
gm
# Out:
# 178.6775

# %%
display(Image.open('./pics/anova.png')) # Src: Internet
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=750x370>

# %%
display(Image.open('./pics/vars.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1539x530>

# %% [markdown]
# - To plot a given list of data as a normal distribution (Gaussian distribution) in Python, you can use libraries like matplotlib, seaborn, and scipy.stats. Below are two approaches:
# - Method 1: Histogram with Fitted Normal Curve

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Sample data (replace with your list)
data = np.random.normal(loc=50, scale=10, size=1000)  # Normally distributed data

# Plot histogram
plt.hist(data, bins=30, density=True, alpha=0.6, color='skyblue', edgecolor='black')

# Fit a normal distribution to the data
mu, std = norm.fit(data)  # Mean (μ) and Standard Deviation (σ)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)  # Probability Density Function (PDF)

# Plot the fitted normal curve
plt.plot(x, p, 'r--', linewidth=2, label=f'Normal Fit (μ={mu:.2f}, σ={std:.2f})')

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.title('Histogram with Fitted Normal Distribution')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# - Method 2: Kernel Density Estimate (KDE) Plot (Seaborn))

# %%
import seaborn as sns
import numpy as np

# Sample data (replace with your list)
data = np.random.normal(loc=50, scale=10, size=1000)

# Plot KDE (automatically fits a smooth curve)
sns.kdeplot(data, color='blue', fill=True, alpha=0.3, label='KDE Estimate')

# Overlay the theoretical normal distribution
mu, std = data.mean(), data.std()
x = np.linspace(mu - 3*std, mu + 3*std, 100)
plt.plot(x, norm.pdf(x, mu, std), 'r--', label=f'Normal (μ={mu:.2f}, σ={std:.2f})')

# Customize plot
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('KDE vs. Normal Distribution')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# Define the parameters for the normal distributions
params = [
    {'mean': 0, 'std': 1, 'label': 'N(0, 1)'},
    {'mean': 2, 'std': 0.5, 'label': 'N(2, 0.5)'},
    {'mean': -1, 'std': 1.5, 'label': 'N(-1, 1.5)'},
    {'mean': 1, 'std': 0.8, 'label': 'N(1, 0.8)'}
]

# Create the figure and subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
axes = axes.flatten()  # Flatten the 2x2 array of axes for easier iteration

# Generate x values for the plots
x = np.linspace(-5, 5, 100)

# Plot the normal distributions on each subplot
for i, param in enumerate(params):
    mean, std, label = param['mean'], param['std'], param['label']
    pdf = stats.norm.pdf(x, loc=mean, scale=std)
    axes[i].plot(x, pdf, label=label)
    axes[i].set_title(f'Normal Distribution: {label}')
    axes[i].set_xlabel('x')
    axes[i].set_ylabel('Probability Density')
    axes[i].legend()

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# Create the figure and subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
axes = axes.flatten()  # Flatten the 2x2 array of axes for easier iteration

#  Prepare Data Keys/Columns
keys = ['octane87', 'octane89', 'octane91', 'octane93']

# Plot the normal distributions on each subplot
for i, key in enumerate(keys):
    # Plot histogram
    axes[i].hist(df[key], bins=30, density=True, alpha=0.6, color='skyblue', edgecolor='black')
    
    # Fit a normal distribution to the data
    mu, std = norm.fit(df[key])  # Mean (μ) and Standard Deviation (σ)
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)  # Probability Density Function (PDF)
    
    # Plot the fitted normal curve
    axes[i].plot(x, p, 'r--', linewidth=2, label=f'Normal Fit (μ={mu:.2f}, σ={std:.2f})')
    
    # Add labels and legend
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Probability Density')
    axes[i].set_title('Histogram with Fitted Normal Distribution')
    axes[i].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Mean Square & Variance
# - The mean square is an estimate of variance!
# $$Sample\ Variance\ =\ S^2\ =\ \frac{\sum(x-\bar{x})^2}{n-1}\ =\ \frac{Sum\ of\ Squares}{Degrees\ of\ Freedom}$$
# $$Mean\ Square\ =\ \frac{Sum\ of\ Squares}{Degrees\ of\ Freedom}$$
#
# #### Why Use Variance For Population Means?
# - $H_o: \mu_a= \mu_b = \mu_c=...\mu_k$
# - ANOVA Analysis translates our data into two different estimates of population varaition.
#   - Treatment and Errors
#   - If the null hypothesis is true, then the treatment variation (MST) could be fully explained by the random nature of the data (MSE). (MST=MSE).
#     - The mean square of errors, $MS_E$,  variation within a treatment (each octane number). The mean square of the error is an estimate of the population variance based on the variation within each treatement group.
#     - $MS_T$, the mean square of the treatment,  is an estimate of the population variance that is based on the variation between the treatment group.
# - The means as can be seen here (169.67000000000002, 175.3, 182.25, 187.49)are different and obviously the $H_o$ is not true. But how do we make decisions statistically?
# - We can make a statiscal conclusion on our null hypothesis by comparing those two estimate of variance. F-value be calculated to make decision.
# $$F-statistic\ =\ \frac{MST}{MSE}$$
#
# - If the null hypothesis is false, then the treatment variation(MST) will be much larger than the error variation (MSE). $MST>>MSE \rightarrow\ F-statistic>>1$
# - If the null hypothesis is true, MST and MSE are equal and $F-statistic=1$.
#
#
# #### Sum of Squares
# $$SS_t\ =\ \sum n(\bar{x}-GM)^2$$
# - $where\ GM=Grand\ Mean,\ n=Treatment\ Sample\ Size. \bar{X_i}=individual\ sample\ means$

# %%
means = df.mean().tolist()
gm = df.to_numpy().mean()

sst= sum([df.shape[0]*(m-gm)**2 for m in means])
sst
# Out:
# 1829.6547499999979

# %% [markdown]
# - Error Sum of Square
# $$SS_e\ =\ \sum n(x_i-\bar{X_i})^2$$
# - $where\ x_i=Individual\ values,\ \bar{X_i}=individual\ sample\ means$

# %%
sse = np.array([df['octane87'].tolist(), 
                df['octane89'].tolist(),
                df['octane91'].tolist(), 
                df['octane93'].tolist()])

sse1 = sse.copy()
for i in range(len(means)):
    sse[i, :] = sse[i, :] - means[i]

sse =np.square(sse)
sse.sum()
# Out:
# 147.93499999999977

# %% [markdown]
# - Total SUm of Squares
# - $SS_{total}=SS_t + SS_e = \sum(x_i - GM)^2$

# %%
np.sum(np.square(sse1-gm)), sst.sum()+sse.sum()
# Out:
# (1977.5897499999992, 1977.5897499999976)

# %% [markdown]
# #### Degree of Freedom
# - $DF_t\ =\ DF_{treatment}=\alpha -1$
#   - $\alpha$ is the number of treatments (levels)=4
# - $DF_e\ =\ DF_{error}=\alpha(n -1)$
#   - $n=$ number of samples per treatment group=10
# - $DF_{total}\ =\ DF_t + DF_e=N-1$
#   - $N$: Total number all elements in all treatments, 4x10=40
#   - $DF_{total}\ =40-1=39$

# %% [markdown]
# #### Mean Squares
# - $MS_E = \frac{SS_E}{DF_E}$
# - $MS_T = \frac{SS_T}{DF_T}$

# %% [markdown]
# #### F-Value
# - $F-statistic =\frac{MS_T}{MS_E}\ =\ \frac{Mean\ Square\ of\ The\ Treatment}{Mean\ Square\ of\ Error}$
# - Accept $H_o$ if $F-statistic =\frac{MS_T}{MS_E}\ =\ \frac{Variation\ b/n\ Treatments}{Variation\ Within\ Treatments}\approx 1$
# - Reject $H_o$ if $F-statistic =\frac{MS_T}{MS_E}\ =\ \frac{Variation\ b/n\ Treatments}{Variation\ Within\ Treatments}= Large Number$
# - Upper Critical Value of F-Distribution, $F_D = F_{\alpha}(\nu_1, \nu_2)$, at specific $\alpha$ level relative to $DF_1$ and $DF_2$.
#   - $\nu_1$ is the degree of freedom of the MST, 3
#   - $\nu_2$ is the degree of freedom of the MSE, 36

# %% [markdown]
# #### One Factor ANOVA Table
# |Variation Source|Sum of Squares|Degrees of Freedom|Mean Squares|F-Value|
# |---|---|---|---|---|
# |Treatments(Between)|$SS_t\ =\ \sum n(\bar{x}-GM)^2$|$DF_t\ =\ DF_{treatment}=\alpha -1$|$MS_T = \frac{SS_T}{DF_T}$|$F =\frac{MS_T}{MS_E}$|
# |Error(Within)|$SS_e\ =\ \sum (x_i-\bar{X_i})^2$|$DF_e\ =\ DF_{error}=\alpha(n -1)$|$MS_E = \frac{SS_E}{DF_E}$||
# |Total|$SS_{total}=SS_t + SS_e = \sum(x_i - GM)^2$|$DF_{total}\ =\ DF_t + DF_e=N-1$|||
#
# |Variation Source|Sum of Squares|Degrees of Freedom|Mean Squares|F-Value|
# |---|---|---|---|---|
# |Treatments(Between)|$1830$|$3$|$610$|$F =\frac{610}{4.1}=148.38$|
# |Error(Within)|$148$|$36$|$4.1$||
# |Total|$1978$|$39$|||
#
#
# #### Conclusion of DoE
# - The F-value os way too big and we can simply reject the null hypothesis. However, how do we make the accept/reject decision for our hypothesis test? **Use The Critical F-Value**.
# - If null hypothesis is false, then the treatment variation (MST) will be much larger than the error variation(MSE). $MST>>MSE$
# - When we don ANOVA-we always perform a right-tail test because our rejection region should capture Large F-values so that we can reject the null hypothesis when it is false.
# - If the null hypothesis is true, then the treatment variation (MST) could be fully explained by the random nature of the data(MMSE). $MST=MSE$
# - Compute F Distribution at $\alpha=0.05,\ (\nu_1, \nu_2) = (3, 36) = 2.866$
# - Any F-statistic above the critical value is rejected!

# %%
from scipy.stats import f
# f_value = f.ppf(1 - alpha, df1, df2)
f_value = f.ppf(1 - 0.05, 3, 36)
f_value
# Out:
# 2.86626555094018

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

# Define degrees of freedom
dfn = 3  # degrees of freedom numerator
dfd = 36 # degrees of freedom denominator
alpha = 0.05 # significance level

# Generate x values
x = np.linspace(0, 5, 500)

# Calculate the F-distribution probability density function (PDF)
pdf = f.pdf(x, dfn, dfd)

# Plot the F-distribution
plt.figure(figsize=(8, 6))
plt.plot(x, pdf, label=f'F({dfn}, {dfd})', color='r')
plt.title('F-Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

dfn = 3  # numerator degrees of freedom
dfd = 36 # denominator degrees of freedom
alpha = 0.05 # significance level

x = np.linspace(0, 5, 500)
f_dist = stats.f.pdf(x, dfn, dfd)

critical_value = stats.f.ppf(1 - alpha, dfn, dfd)

plt.plot(x, f_dist, label=f'F({dfn}, {dfd}) distribution')

x_rejection = np.linspace(critical_value, 5, 100)
y_rejection = stats.f.pdf(x_rejection, dfn, dfd)
plt.fill_between(x_rejection, y_rejection, color='red', alpha=0.3, 
                 label=f'Rejection region ($\\alpha$ = {alpha})')

plt.axvline(critical_value, color='red', linestyle='--', 
            label=f'Critical value = {critical_value:.2f}')

plt.xlabel('F-statistic')
plt.ylabel('Probability density')
plt.title('F-distribution with rejection region')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# - **Because the F-Statistic(148.8) is way greater than our critical F-value (2.866), we must reject the null hypothesis ($H_o$) in favor of the alternative hypothesis ($H_a$)**.
# - The Octane Gas Level has an impact on the car's horsepower!

# %%
ANOVA: https://www.youtube.com/watch?v=g5HlLOwcXuI
